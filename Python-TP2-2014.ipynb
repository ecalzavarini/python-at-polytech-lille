# %% [markdown]
# ##### TP 2 -- Informatique CM3 -- Septembre 2014

# %% [markdown]
# # Python @ Polytech'Lille

# %% [markdown]
# ##### Utiliser les fonctions en Python

# %% [markdown]
# Vous savez déjà ce qui est une fonction mathématique d'une variable réelle
# Considérons par exemple la fonction affine f(x) suivante définie:
#
# f : x ---> 2 x + 1
#
# Pour la définir en Python :

# %%
#definition d'une fonction
def f(x):
    return 2 * x + 1

#utilisation de la fonction

print(f(4))
# Out:
# 9

# %% [markdown]
# Vous avez remarqué qu’à la deuxième ligne, on n’a pas commencé à écrire au début de la ligne. On dit qu’on fait une indentation. Et cette indentation est indispensable pour que Python fasse son travail.

# %% [markdown]
# Le principe de définition de fonctions est intéressant pour au moins deux raisons:
#
# cela nous permet de ne pas répéter un calcul long à taper,
# car Python possède un type spécial dédié au fonctions, que l’on peut donc manipuler, mettre dans des listes pour les étudier les unes à la suite des autres. Par exemple :

# %%
print( type(f))
# Out:
# <type 'function'>

# %%
# definition d'une seconde fonction
def hi(name):
    print("hello " + name + " from Python!!!")

#exemple d'utilisation    
hi("Mark")
# Out:
# hello Mark from Python!!!

# %%
#definition  d'une trosieme fonction
from random import choice
def lettre():
    return choice('abcdefghijklmnopqrstuvwxyz')

#exemple d'utilisation 
lettre()
# Out:
# 's'

# %%
#definition d'une liste de fonctions
mes_fonctions = [f,hi,lettre]

#utilisation
mes_fonctions[1]("Dominique")

mes_fonctions[2]()
# Out:
# hello Dominique from Python!!!
# 'e'

# %% [markdown]
# #### Script 1

# %% [markdown]
# L’objet de ce script est d'illustrer à de Python les rôles respectifs sont joués par le ressort et l’amortisseur d’un système automobile. Pour ce faire, nous étudions un ressort couplé à un amortisseur en parallèle.
# Comme dans la figure ci-dessous:

# %%
from IPython.display import Image
Image(filename='masse-ressort-amortisseur.jpg')

# %% [markdown]
# L'équation vérifiée par le système est la suivante :
#
# $$ \ddot{x} + \frac{\omega_0}{Q} \dot{x} + \omega_0^2\ x = \frac{F}{m} \cos( \omega t) $$

# %% [markdown]
# De la solution de cette equation on toruve la fonction de transfert qui décrit la réponse du systeme en fonction de la pulsation $\omega$.
#
# En particulier le module de la fonction de transfert s'écrit :

# %% [markdown]
# $$ |H(\omega)| = \frac{1}{\omega_0^2} \frac{1}{\sqrt{ \left( 1 - \omega^2/\omega_0^2 \right)^2 + Q^{-2} \omega^2/\omega_0^2 }} $$

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open('custom.css', 'r').read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=Fenix' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'Fenix', serif;
#     }
#     h3{
# 	font-family: 'Fenix', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#        h4{
# 	font-family: 'Fenix', serif;
#        }
#     h5 {
# ...
